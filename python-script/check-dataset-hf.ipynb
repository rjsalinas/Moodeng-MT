# %%
from datasets import load_dataset

# Load main branch
main_ds = load_dataset("propanda02/TweetTaglish-SalinTala", split="train", revision="main")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...
# Generating validation split: 100%|██████████| 1810/1810 [00:00<00:00, 602371.68 examples/s]

# %%
print("Main:", len(main_ds))
# Out:
# Main: 7239

# %%
# print(main_ds[])
# search the dataset for id '12'
main_ds.filter(lambda x: x['id'] == 12)
# Out:
# Filter: 100%|██████████| 7239/7239 [00:00<00:00, 229577.68 examples/s]
# Dataset({
#     features: ['id', 'translation'],
#     num_rows: 0
# })

# %%
main_ds.to_pandas().sample()
# Out:
#         id                                        translation
# 5701  5702  {'en': '"I just received the mail and gift, bu...
